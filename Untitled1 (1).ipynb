# %%
# !pip install nltk scikit-learn pandas joblib

# %%
import re
import pandas as pd
import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, accuracy_score

import joblib

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# ==============================
# Ejemplos de mensajes SPAM
# ==============================

spam_texts = [
"¡Felicidades! Has ganado un iPhone gratis. Haz clic aquí para reclamar tu premio.",
"Gana dinero rápido desde casa sin experiencia. Regístrate ahora.",
"Oferta limitada: 80% de descuento en todos los productos. Compra hoy.",
"Has sido seleccionado para recibir un premio de $1000.",
"Promoción exclusiva solo por hoy. Reclama tu regalo gratis.",
"Tu número fue elegido para ganar un premio especial.",
"Obtén préstamos inmediatos sin revisar historial crediticio.",
"Gana dinero fácil trabajando solo 2 horas al día.",
"¡Última oportunidad! Reclama tu bono ahora mismo.",
"Has sido seleccionado para participar en nuestra promoción.",
"Recibe premios gratis solo por registrarte en este enlace.",
"Oferta especial: compra uno y recibe dos gratis.",
"Ganaste una tarjeta de regalo. Reclámala ahora.",
"Invitación exclusiva para ganar dinero en línea.",
"Aprovecha esta promoción antes de que termine.",
"Gana premios increíbles registrándote hoy.",
"Tu cuenta fue seleccionada para recibir beneficios especiales.",
"Promoción limitada para nuevos usuarios.",
"Obtén ingresos extra desde tu celular fácilmente.",
"Participa ahora y gana premios increíbles."
]

# ==============================
# Ejemplos de mensajes normales
# ==============================

ham_texts = [
"Hola, ¿cómo estás?",
"Nos vemos mañana en la escuela.",
"¿Ya terminaste la tarea de matemáticas?",
"Te mando el archivo que me pediste.",
"Vamos a comer a las 3 de la tarde.",
"Recuerda traer tu cuaderno mañana.",
"Estoy estudiando para el examen.",
"¿Puedes ayudarme con este ejercicio?",
"La clase empieza a las ocho.",
"Te veo más tarde en la biblioteca.",
"Acabo de llegar a casa.",
"¿Ya revisaste el correo que te envié?",
"Nos reunimos para hacer el proyecto.",
"Hoy tenemos entrenamiento en la tarde.",
"Avísame cuando llegues.",
"Estoy haciendo la tarea de programación.",
"Mañana tenemos presentación en clase.",
"¿Quieres salir a caminar después?",
"Voy a enviar el documento en un momento.",
"Gracias por tu ayuda con el proyecto."
]

all_messages = spam_texts + ham_texts
labels = ["spam"] * len(spam_texts) + ["ham"] * len(ham_texts)

data = pd.DataFrame({
    "texto": all_messages,
    "clase": labels
})

data.head()
# Out:
#                                                texto clase
# 0  ¡Felicidades! Has ganado un iPhone gratis. Haz...  spam
# 1  Gana dinero rápido desde casa sin experiencia....  spam
# 2  Oferta limitada: 80% de descuento en todos los...  spam
# 3  Has sido seleccionado para recibir un premio d...  spam
# 4  Promoción exclusiva solo por hoy. Reclama tu r...  spam

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

data["texto_limpio"] = data["texto"].apply(clean_text)

# %%
stop_words = set(stopwords.words("spanish") + stopwords.words("english"))

def remove_stopwords(text):
    words = text.split()
    filtered = [w for w in words if w not in stop_words]
    return " ".join(filtered)

data["texto_procesado"] = data["texto_limpio"].apply(remove_stopwords)

data.head()
# Out:
#                                                texto clase  \
# 0  ¡Felicidades! Has ganado un iPhone gratis. Haz...  spam
# 1  Gana dinero rápido desde casa sin experiencia....  spam
# 2  Oferta limitada: 80% de descuento en todos los...  spam
# 3  Has sido seleccionado para recibir un premio d...  spam
# 4  Promoción exclusiva solo por hoy. Reclama tu r...  spam
#
#                                         texto_limpio  \
# 0  felicidades has ganado un iphone gratis haz cl...
# 1  gana dinero rpido desde casa sin experiencia r...
# 2  oferta limitada de descuento en todos los prod...
# 3    has sido seleccionado para recibir un premio de
# 4  promocin exclusiva solo por hoy reclama tu reg...
#
#                                      texto_procesado
# 0  felicidades ganado iphone gratis haz clic aqu ...
# 1  gana dinero rpido casa experiencia regstrate a...
# 2     oferta limitada descuento productos compra hoy
# 3                   sido seleccionado recibir premio
# ...

# %%
vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(data["texto_procesado"])
y = data["clase"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=123
)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("Matriz de confusión:")
print(cm)

print("Precisión:", accuracy)
# Out:
# Matriz de confusión:
# [[2 0]
#  [1 5]]
# Precisión: 0.875

# %%
joblib.dump(model, "modelo_spam_nb.pkl")
joblib.dump(vectorizer, "vectorizer_tfidf.pkl")

print("Modelo guardado")
# Out:
# Modelo guardado

# %%
new_message = ["Congratulations you won a free prize click now"]

cleaned = clean_text(new_message[0])
processed = remove_stopwords(cleaned)

vec = vectorizer.transform([processed])

pred = model.predict(vec)[0]
proba = model.predict_proba(vec)[0]

confidence = max(proba) * 100

print("Mensaje:", new_message[0])
print("Predicción:", pred)
print("Confianza:", confidence)
# Out:
# Mensaje: Congratulations you won a free prize click now
# Predicción: ham
# Confianza: 56.25
